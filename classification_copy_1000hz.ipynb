# %%
from scipy.io import loadmat
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
#np.set_printoptions(threshold=1000)

# %%
# load the data from the .mat file

data = loadmat('data/sp1s_aa_1000hz.mat')

# %% [markdown]
# sp1s_aa.mat is a Matlab format (*.mat) containing variables:
# > clab: electrode labels
# > x_train: training trials (time x channels x trials)
# > y_train: corresponding labels (0: left, 1: right)
# > x_test: test trials (time x channels x trials)

# %%
# check the dictionary keys to ensure correct variables loaded

data.keys()
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'clab', 'x_train', 'y_train', 'x_test'])

# %%
# check the shapes
print('Shape of clab: ', data['clab'].shape)
print('Shape of x_train: ', data['x_train'].shape)
print('Shape of y_train: ', data['y_train'].shape)
print('Shape of x_test: ', data['x_test'].shape)
# Out:
# Shape of clab:  (1, 28)
# Shape of x_train:  (500, 28, 316)
# Shape of y_train:  (1, 316)
# Shape of x_test:  (500, 28, 100)

# %%
# create new variables from keys

clab = data['clab']
x_train = data['x_train']
y_train = data['y_train']
x_test = data['x_test']

# %%
label_list = []
for i in clab[0]:
    label_list.append(i[0])
print(label_list)
# Out:
# ['F3', 'F1', 'Fz', 'F2', 'F4', 'FC5', 'FC3', 'FC1', 'FCz', 'FC2', 'FC4', 'FC6', 'C5', 'C3', 'C1', 'Cz', 'C2', 'C4', 'C6', 'CP5', 'CP3', 'CP1', 'CPz', 'CP2', 'CP4', 'CP6', 'O1', 'O2']

# %%
x_train[:,:,0]
# Out:
# array([[ 30.8, -22.6,  11.2, ...,   0.5,  11. ,  -9.9],
#        [ 33.1, -19.2,  16.7, ...,   0.5,  10.6, -10. ],
#        [ 37.9, -11.8,  26.4, ...,   0.4,   9.8, -10.3],
#        ...,
#        [ 76.9,  26.8,  64.1, ...,  45.1,  41.7,  32.9],
#        [ 75.9,  22.9,  62. , ...,  46.2,  41.5,  33.8],
#        [ 72.3,  16.4,  55.9, ...,  46.6,  40.9,  32.8]])

# %%
df = pd.DataFrame(x_train[:,:,0], columns = label_list)

# %%
df
# Out:
#        F3    F1    Fz    F2    F4   FC5   FC3   FC1   FCz    FC2  ...    C6  \
# 0    30.8 -22.6  11.2   6.0   2.4  -9.3  -7.8 -18.7  35.3   47.7  ...  -3.6
# 1    33.1 -19.2  16.7   9.9   5.0  -6.6  -5.5 -15.7  37.5   49.5  ...  -3.7
# 2    37.9 -11.8  26.4  18.2  10.2  -1.7  -1.2 -10.9  42.5   53.6  ...  -2.6
# 3    43.5  -2.9  35.7  26.7  15.2   3.9   3.6  -6.2  48.0   58.2  ...  -0.3
# 4    46.1   0.2  40.1  30.8  17.0   6.8   6.0  -4.1  50.7   60.5  ...   1.3
# ..    ...   ...   ...   ...   ...   ...   ...   ...   ...    ...  ...   ...
# 495  73.6  22.9  65.2  62.3  72.3  30.6  32.7  32.1  95.7  111.2  ...  47.2
# 496  76.1  26.5  64.8  63.2  76.5  31.8  33.1  32.2  96.2  112.0  ...  48.1
# 497  76.9  26.8  64.1  63.5  76.3  32.4  33.2  31.7  96.1  111.7  ...  48.2
# 498  75.9  22.9  62.0  61.4  70.5  32.6  33.0  30.3  94.5  109.7  ...  47.5
# 499  72.3  16.4  55.9  55.0  61.0  30.7  30.6  26.7  89.8  105.1  ...  45.6
#
#       CP5   CP3   CP1   CPz    CP2   CP4   CP6    O1    O2
# 0    31.6   1.1  15.1  23.2   52.0  20.3   0.5  11.0  -9.9
# 1    32.0   1.7  15.5  23.2   52.3  20.2   0.5  10.6 -10.0
# 2    31.1   1.5  15.8  23.0   52.3  19.8   0.4   9.8 -10.3
# 3    31.1   2.6  17.3  24.5   53.9  21.1   1.7  10.7  -9.0
# 4    32.6   4.8  19.6  28.0   56.9  24.2   3.9  13.5  -5.9
# ..    ...   ...   ...   ...    ...   ...   ...   ...   ...
# 495  64.0  39.9  60.4  69.3  102.0  66.2  47.3  46.2  35.0
# 496  60.4  35.6  56.6  66.9   99.4  64.4  45.5  43.4  33.1
# 497  58.5  33.2  54.7  66.6   98.8  63.9  45.1  41.7  32.9
# 498  59.1  33.5  55.5  67.6  100.3  64.4  46.2  41.5  33.8
# 499  60.0  33.8  56.6  67.2  100.7  63.9  46.6  40.9  32.8
#
# [500 rows x 28 columns]

# %%
plt.rcParams['figure.figsize'] = [15, 5]


df.plot(y='F3', use_index = True)
# Out:
# <AxesSubplot:>

# %%
plt.rcParams['figure.figsize'] = [15, 28*5]

df.plot(subplots=True)
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#        <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#        <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#        <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#        <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#        <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#        <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#       dtype=object)

# %%
plt.rcParams['figure.figsize'] = [15, 5]


df.plot()
# Out:
# <AxesSubplot:>
